# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhanupriya-Ai/Python-Programming-Practice/blob/main/Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Function
def function_name(parameter name);
statement 1
statement 2
return variable
function_name(parameter name)

# %%
#take nothing return nothing
def sum():
    var1=int(input("enter 1st num"))
    var2=int(input("enter 2nd num"))
    print(var1+var2)
sum()
# Out:
# enter 1st num5
# enter 2nd num7
# 12

# %%
#take something return nothing
def sum(var1,var2):
    print(var1+var2)
a=int(input("enter 1st num"))
b=int(input("enter 2nd num"))
sum(a,b)
# Out:
# enter 1st num5
# enter 2nd num7
# 12

# %%
#take nothing return something
def sum():
    a=10
    b=5
    return a+b
result=sum()
print(result)
# Out:
# 15

# %%
#take something return something
def sum(a,b):
    return a+b
result=sum(12,8)
print(result)
# Out:
# 20
