# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhanupriya-Ai/Python-Programming-Practice/blob/main/Python_Basics_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello python")
# Out:
# hello python

# %%
print("Hello Python1", end = " ")
print("Hello python2")
# Out:
# Hello Python1 Hello python2

# %%
var = 10
print(var)
print(type(var))
var = "python"
print(var)
print(type(var))
# Out:
# 10
# <class 'int'>
# python
# <class 'str'>

# %%
var="python"
print(var)
print(var[3])
print(var[-2])
# Out:
# python
# h
# o

# %%
var="programming"
print(var[1:6])
print(var[1:7:2])
# Out:
# rogra
# rga

# %%
var="python"
print(var[1:5:2])
# Out:
# yh

# %%
var="python"
print(var[::-1])
# Out:
# nohtyp

# %%
var="python programming"
print(len(var))
print(var.upper())
print(var.lower())
print(var.title())
print(var.capitalize())
# Out:
# 18
# PYTHON PROGRAMMING
# python programming
# Python Programming
# Python programming
